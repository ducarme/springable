# %% [markdown]
# ### Starting a simulation

# %%
import src.springable.simulation as ss

# %%
ss.simulate_model('examples/von_mises_truss.csv', 'test')
# Out:
# Solving progress (step 1/1): [##########] (364/10000) --> final force for loading step 1 has been reached
# Full equilibrium path was retrieved increments = 364 | stiffness matrix eval = 755 | linear system resolutions = 1144
# Solving duration: 0.9564 s
# Generating GIF animation...
# Progress: [##########] (100/100)
# GIF animation saved successfully
